# %%
# import pandas & numpy library
import numpy as np
import pandas as pd

# %%
#Get CSV from Local file 
#(the csv file must be uploaded to jupyter notebook's File)
data = pd.read_csv('Education.csv', header =3) #(header=3 fixes the headers)
data = data.iloc[1:]
data.head()
# Out:
#    Federal Information Processing Standard (FIPS) Code State       Area name  \
# 1                                               1000      AL         Alabama
# 2                                               1001      AL  Autauga County
# 3                                               1003      AL  Baldwin County
# 4                                               1005      AL  Barbour County
# 5                                               1007      AL     Bibb County
#
#    2003 Rural-urban Continuum Code  2003 Urban Influence Code  \
# 1                              NaN                        NaN
# 2                              2.0                        2.0
# 3                              4.0                        5.0
# 4                              6.0                        6.0
# 5                              1.0                        1.0
#
#    2013 Rural-urban Continuum Code  2013 Urban Influence Code  \
# 1                              NaN                        NaN
# ...

# %%
#Showing only Alameda County and Merced
A_M = data[(data['Area name'] == 'Alameda County') | (data['Area name'] == 'Merced County')]

#Display the whole table
pd.options.display.max_columns = None
display(A_M)
# Out:
#      Federal Information Processing Standard (FIPS) Code State  \
# 201                                               6001      CA
# 224                                               6047      CA
#
#           Area name  2003 Rural-urban Continuum Code  \
# 201  Alameda County                              1.0
# 224   Merced County                              3.0
#
#      2003 Urban Influence Code  2013 Rural-urban Continuum Code  \
# 201                        1.0                              1.0
# 224                        2.0                              2.0
#
#      2013 Urban Influence Code Less than a high school diploma, 1970  \
# 201                        1.0                               217,589
# 224                        2.0                                25,247
#
#     High school diploma only, 1970 Some college (1-3 years), 1970  \
# 201                        197,371                         87,675
# 224                         15,455                          6,219
#
# ...

# %%
#Selecting specific columns

AMY = A_M.drop(A_M.iloc[:, 3:47], axis=1)
display(AMY)
# Out:
#      Federal Information Processing Standard (FIPS) Code State  \
# 201                                               6001      CA
# 224                                               6047      CA
#
#           Area name Less than a high school diploma, 2017-21  \
# 201  Alameda County                                  131,272
# 224   Merced County                                   49,054
#
#     High school diploma only, 2017-21  \
# 201                           198,825
# 224                            43,880
#
#     Some college or associate's degree, 2017-21  \
# 201                                     271,096
# 224                                      49,268
#
#     Bachelor's degree or higher, 2017-21  \
# 201                              592,670
# 224                               23,259
#
#      Percent of adults with less than a high school diploma, 2017-21  \
# 201                                               11.0
# 224                                               29.6
#
# ...
